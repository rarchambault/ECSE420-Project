# %%
# %%writefile constants.cuh
# #ifndef CONSTANTS_H
# #define CONSTANTS_H
#
# #define WINDOW_WIDTH 800
# #define WINDOW_HEIGHT 600
# #define PARTICLE_RADIUS 5.0f
#
# #define MAX_LEFT PARTICLE_RADIUS
# #define MAX_RIGHT (WINDOW_WIDTH - PARTICLE_RADIUS)
# #define MAX_TOP PARTICLE_RADIUS
# #define MAX_BOTTOM (WINDOW_HEIGHT - PARTICLE_RADIUS)
#
# #define GRAVITY 250.0f
# #define DAMPING_FACTOR 0.9f
#
# #define GRID_CELL_SIZE (PARTICLE_RADIUS * 2.0f)
# #define GRID_WIDTH (WINDOW_WIDTH / GRID_CELL_SIZE)
# #define GRID_HEIGHT (WINDOW_HEIGHT / GRID_CELL_SIZE)
# #define MAX_PARTICLES_PER_CELL 16
#
# #endif // CONSTANTS_H
# Out:
# Overwriting constants.cuh

# %%
# %%writefile collisions.cuh
# #ifndef COLLISIONS_H
# #define COLLISIONS_H
#
# #include "constants.cuh"
# #include <cuda_runtime.h>
#
#
# #ifdef __cplusplus
# extern "C" {
# #endif
#
# typedef struct {
#     float2 position;
#     float2 velocity;
#     float  radius;
# } Particle;
#
#
# typedef struct {
#     float2 position;
#     float radius;
# } Obstacle;
#
#
# void runCollisionStep(Particle *d_particles, int *d_gridCounters, int *d_gridIndices, int numParticles);
#
# #ifdef __cplusplus
# }
# #endif
#
# #endif // COLLISIONS_H
# Out:
# Overwriting collisions.cuh

# %%
# %%writefile collisions.cu
# #include "collisions.cuh"
# #include "constants.cuh"
# #include <cuda_runtime.h>
# #include <device_launch_parameters.h>
# #include <math.h>
#
# // Collision resolution kernel: For each particle, check its neighborhood in the grid
# // and resolve any overlaps with other particles.
# __global__ void resolveCollisionsKernel(Particle *particles, int *gridCounters, int *gridIndices, int numParticles) {
#     int i = blockIdx.x * blockDim.x + threadIdx.x;
#     if (i >= numParticles) return;
#
#     Particle p = particles[i];
#
#     // Determine particle's cell
#     int cellX = (int)(p.position.x / GRID_CELL_SIZE);
#     int cellY = (int)(p.position.y / GRID_CELL_SIZE);
#
#     // Loop over 3x3 neighborhood
#     for (int offsetY = -1; offsetY <= 1; offsetY++) {
#         for (int offsetX = -1; offsetX <= 1; offsetX++) {
#             int neighborX = cellX + offsetX;
#             int neighborY = cellY + offsetY;
#
#             // Skip if outside grid
#             if (neighborX < 0 || neighborX >= GRID_WIDTH ||
#                 neighborY < 0 || neighborY >= GRID_HEIGHT)
#                 continue;
#
#             int neighborIndex = neighborY * GRID_WIDTH + neighborX;
#             int count = gridCounters[neighborIndex];
#
#             for (int j = 0; j < count; j++) {
#                 int otherIndex = gridIndices[neighborIndex * MAX_PARTICLES_PER_CELL + j];
#                 if (otherIndex == i) continue;
#
#                 Particle other = particles[otherIndex];
#
#                 float dx = other.position.x - p.position.x;
#                 float dy = other.position.y - p.position.y;
#                 float distance = sqrtf(dx * dx + dy * dy);
#                 float minDist = p.radius + other.radius;
#
#                 if (distance < minDist && distance > 0.0f) {
#                     // Normalize collision normal
#                     float normX = dx / distance;
#                     float normY = dy / distance;
#
#                     // Push particles apart
#                     float overlap = (minDist - distance) * 0.5f;
#                     p.position.x -= overlap * normX;
#                     p.position.y -= overlap * normY;
#
#                     // Reflect velocity
#                     float vDotN = p.velocity.x * normX + p.velocity.y * normY;
#                     if (vDotN > 0.0f) vDotN = 0.0f;
#
#                     p.velocity.x -= 2.0f * vDotN * normX;
#                     p.velocity.y -= 2.0f * vDotN * normY;
#
#                     // Dampen
#                     p.velocity.x *= DAMPING_FACTOR;
#                     p.velocity.y *= DAMPING_FACTOR;
#
#                     // Wake-up nudge if velocity is too low
#                     float speed2 = p.velocity.x * p.velocity.x + p.velocity.y * p.velocity.y;
#                     if (speed2 < 1e-4f) {
#
#                         p.velocity.x += 0.1f * normX;
#                         p.velocity.y += 0.1f * normY;
#                     }
#                 }
#             }
#         }
#     }
#
#     float jitter = 0.05f;
#     p.velocity.x += jitter * ((i % 2 == 0) ? 1.0f : -1.0f); // pseudo-random X
#     p.velocity.y += jitter * ((i % 3 == 0) ? 1.0f : -1.0f); // pseudo-random Y
#
#     particles[i] = p;
# }
#
# __global__ void resolveCollisionsKernelSymmetric(Particle *particles,
#                                                    int *gridCounters,
#                                                    int *gridIndices,
#                                                    int numParticles) {
#     int i = blockIdx.x * blockDim.x + threadIdx.x;
#     if (i >= numParticles) return;
#
#     // Load particle i (local copy is ok for reading cell info)
#     Particle p = particles[i];
#
#     // Determine particle's cell
#     int cellX = (int)(p.position.x / GRID_CELL_SIZE);
#     int cellY = (int)(p.position.y / GRID_CELL_SIZE);
#
#     // Loop over the 3x3 neighborhood of cells.
#     for (int offsetY = -1; offsetY <= 1; offsetY++) {
#         for (int offsetX = -1; offsetX <= 1; offsetX++) {
#             int neighborX = cellX + offsetX;
#             int neighborY = cellY + offsetY;
#
#             // Skip if neighbor cell is outside the grid.
#             if (neighborX < 0 || neighborX >= GRID_WIDTH ||
#                 neighborY < 0 || neighborY >= GRID_HEIGHT)
#                 continue;
#
#             int neighborCell = neighborY * GRID_WIDTH + neighborX;
#             int count = gridCounters[neighborCell];
#
#             // Check each particle in the neighbor cell.
#             for (int j = 0; j < count; j++) {
#                 int otherIndex = gridIndices[neighborCell * MAX_PARTICLES_PER_CELL + j];
#
#                 // Ensure each pair is processed only once.
#                 if (otherIndex <= i)
#                     continue;
#
#                 // Read the neighbor particle.
#                 Particle other = particles[otherIndex];
#
#                 float dx = other.position.x - p.position.x;
#                 float dy = other.position.y - p.position.y;
#                 float distance = sqrtf(dx * dx + dy * dy);
#                 float minDist = p.radius + other.radius;
#
#                 if (distance < minDist && distance > 0.0f) {
#                     // Calculate normalized collision normal.
#                     float normX = dx / distance;
#                     float normY = dy / distance;
#
#                     // Compute symmetric overlap correction.
#                     float overlap = (minDist - distance) * 0.5f;
#                     atomicAdd(&particles[i].position.x, -overlap * normX);
#                     atomicAdd(&particles[i].position.y, -overlap * normY);
#                     atomicAdd(&particles[otherIndex].position.x, overlap * normX);
#                     atomicAdd(&particles[otherIndex].position.y, overlap * normY);
#
#                     // Compute relative velocity along the collision normal.
#                     float relVel = (other.velocity.x - p.velocity.x) * normX +
#                                    (other.velocity.y - p.velocity.y) * normY;
#
#                     // Only process if particles are moving toward each other.
#                     if (relVel < 0.0f) {
#                         // Use DAMPING_FACTOR as the restitution coefficient.
#                         float restitution = DAMPING_FACTOR;
#                         float impulse = -(1.0f + restitution) * relVel / 2.0f; // Equal mass assumed
#
#                         // Atomically update velocities for both particles.
#                         atomicAdd(&particles[i].velocity.x, -impulse * normX);
#                         atomicAdd(&particles[i].velocity.y, -impulse * normY);
#                         atomicAdd(&particles[otherIndex].velocity.x, impulse * normX);
#                         atomicAdd(&particles[otherIndex].velocity.y, impulse * normY);
#                     }
#                 }
#             }
#         }
#     }
# }
#
#
#
# // Host function to launch the collision resolution kernel.
# void runCollisionStep(Particle *d_particles, int *d_gridCounters, int *d_gridIndices, int numParticles) {
#     int threadsPerBlock = 256;
#     int numBlocks = (numParticles + threadsPerBlock - 1) / threadsPerBlock;
#     resolveCollisionsKernelSymmetric<<<numBlocks, threadsPerBlock>>>(d_particles, d_gridCounters, d_gridIndices, numParticles);
# }
# Out:
# Overwriting collisions.cu

# %%
# %%writefile simulation.cuh
# #ifndef SIMULATION_H
# #define SIMULATION_H
#
# #include "collisions.cuh"  // This header now defines Particle.
# #include "constants.cuh"
# #include <cuda_runtime.h>
#
# #ifdef __cplusplus
# extern "C" {
# #endif
#
# // Run a full simulation step (integration, grid build, collision resolution).
# void runSimulationStep(Particle *d_particles, int numParticles, float deltaTime, float gravity,
#                        int *d_gridCounters, int *d_gridIndices, Obstacle* obstacles,
#     int numObstacles);
# #ifdef __cplusplus
# }
# #endif
#
# #endif // SIMULATION_H
# Out:
# Overwriting simulation.cuh

# %%
# %%writefile simulation.cu
# #include "simulation.cuh"
# #include "collisions.cuh"  // Include the collision module.
# #include "constants.cuh"
# #include <cuda_runtime.h>
# #include <device_launch_parameters.h>
# #include <math.h>
#
# // Integration kernel: Updates particle velocity (with gravity) and position.
# __global__ void integrateParticlesKernel(Particle *particles, int numParticles, float deltaTime, float gravity,
#                                          Obstacle* obstacles, int numObstacles) {
#     int i = blockIdx.x * blockDim.x + threadIdx.x;
#     if (i >= numParticles) return;
#
#     Particle p = particles[i];
#
#     // Gravity
#     p.velocity.y += gravity * deltaTime;
#
#     // Integrate motion
#     p.position.x += p.velocity.x * deltaTime;
#     p.position.y += p.velocity.y * deltaTime;
#
#     // Obstacle collisions
#     for (int o = 0; o < numObstacles; o++) {
#         Obstacle obs = obstacles[o];
#         float dx = p.position.x - obs.position.x;
#         float dy = p.position.y - obs.position.y;
#         float dist = sqrtf(dx * dx + dy * dy);
#         float minDist = p.radius + obs.radius;
#
#         if (dist < minDist && dist > 0.0f) {
#             float normX = dx / dist;
#             float normY = dy / dist;
#             float overlap = minDist - dist;
#
#             p.position.x += normX * overlap;
#             p.position.y += normY * overlap;
#
#             float vDotN = p.velocity.x * normX + p.velocity.y * normY;
#             if (vDotN < 0.0f) {
#                 p.velocity.x -= 2.0f * vDotN * normX;
#                 p.velocity.y -= 2.0f * vDotN * normY;
#             }
#
#             p.velocity.x *= DAMPING_FACTOR;
#             p.velocity.y *= DAMPING_FACTOR;
#         }
#     }
#
#     // Boundary collision
#     if (p.position.x < MAX_LEFT) {
#         p.position.x = MAX_LEFT;
#         p.velocity.x = -p.velocity.x * DAMPING_FACTOR;
#     }
#     if (p.position.x > MAX_RIGHT) {
#         p.position.x = MAX_RIGHT;
#         p.velocity.x = -p.velocity.x * DAMPING_FACTOR;
#     }
#     if (p.position.y < MAX_TOP) {
#         p.position.y = MAX_TOP;
#         p.velocity.y = -p.velocity.y * DAMPING_FACTOR;
#     }
#     if (p.position.y > MAX_BOTTOM) {
#         p.position.y = MAX_BOTTOM;
#         p.velocity.y = -p.velocity.y * DAMPING_FACTOR;
#     }
#
#     particles[i] = p;
# }
#
# // Grid building kernel: Bins particles into a uniform grid using atomic operations.
# __global__ void buildGridKernel(Particle *particles, int numParticles,
#                                 int *gridCounters, int *gridIndices) {
#     int i = blockIdx.x * blockDim.x + threadIdx.x;
#     if (i >= numParticles) return;
#
#     Particle p = particles[i];
#     int cellX = (int)(p.position.x / GRID_CELL_SIZE);
#     int cellY = (int)(p.position.y / GRID_CELL_SIZE);
#
#     cellX = min(max(cellX, 0), static_cast<int>(GRID_WIDTH) - 1);
#     cellY = min(max(cellY, 0), static_cast<int>(GRID_HEIGHT) - 1);
#
#
#     int cellIndex = cellY * GRID_WIDTH + cellX;
#
#     int offset = atomicAdd(&gridCounters[cellIndex], 1);
#     if (offset < MAX_PARTICLES_PER_CELL) {
#         gridIndices[cellIndex * MAX_PARTICLES_PER_CELL + offset] = i;
#     }
# }
#
# // Host function that performs one simulation step.
# void runSimulationStep(Particle *d_particles, int numParticles, float deltaTime, float gravity,
#                        int *d_gridCounters, int *d_gridIndices, Obstacle* obstacles,
#     int numObstacles) {
#     int threadsPerBlock = 256;
#     int numBlocks = (numParticles + threadsPerBlock - 1) / threadsPerBlock;
#
#     // 1. Integration: update particle positions and velocities.
#     integrateParticlesKernel<<<numBlocks, threadsPerBlock>>>(
#         d_particles, numParticles, deltaTime, gravity, obstacles, numObstacles);
#
#     // 2. Reset the grid counters.
#     int numCells = GRID_WIDTH * GRID_HEIGHT;
#     cudaMemset(d_gridCounters, 0, numCells * sizeof(int));
#
#     // 3. Build the uniform grid.
#     buildGridKernel<<<numBlocks, threadsPerBlock>>>(d_particles, numParticles, d_gridCounters, d_gridIndices);
#
#     // 4. Resolve collisions using the dedicated collision module.
#     runCollisionStep(d_particles, d_gridCounters, d_gridIndices, numParticles);
# }
# Out:
# Overwriting simulation.cu

# %%
# %%writefile render.cuh
# #ifndef RENDER_H
# #define RENDER_H
#
# #include "collisions.cuh"  // Uses Particle defined in collisions.h.
# #include "constants.cuh"
# #include <cuda_runtime.h>
#
# #ifdef __cplusplus
# extern "C" {
# #endif
#
# // Render function: writes particle colors to a framebuffer.
# void renderParticles(const Particle* d_particles, int numParticles,
#                      const Obstacle* d_obstacles, int numObstacles,
#                      unsigned char* d_framebuffer, int width, int height, int frameNumber);
#
# #ifdef __cplusplus
# }
# #endif
#
# #endif // RENDER_H
# Out:
# Overwriting render.cuh

# %%
# %%writefile render.cu
# #include "render.cuh"
# #include "constants.cuh"
# #include <cuda_runtime.h>
# #include <device_launch_parameters.h>
#
#
# __global__ void renderParticlesKernel(const Particle* particles, int numParticles,
#                                       const Obstacle* obstacles, int numObstacles,
#                                       unsigned char* framebuffer, int width, int height,
#                                       int frameNumber)
#  {
#     int x = blockIdx.x * blockDim.x + threadIdx.x;
#     int y = blockIdx.y * blockDim.y + threadIdx.y;
#     if (x >= width || y >= height) return;
#
#     int pixelIdx = (y * width + x) * 4;
#
#     // Clear pixel to black.
#     framebuffer[pixelIdx + 0] = 0;
#     framebuffer[pixelIdx + 1] = 0;
#     framebuffer[pixelIdx + 2] = 0;
#     framebuffer[pixelIdx + 3] = 255;
#
#     for (int o = 0; o < numObstacles; o++) {
#       Obstacle obs = obstacles[o];
#       float dx = x - obs.position.x;
#       float dy = y - obs.position.y;
#       if (dx * dx + dy * dy <= obs.radius * obs.radius) {
#           framebuffer[pixelIdx + 0] = 100; // dark gray
#           framebuffer[pixelIdx + 1] = 100;
#           framebuffer[pixelIdx + 2] = 100;
#           framebuffer[pixelIdx + 3] = 255;
#           return; // Don't draw particles here
#       }
#     }
#
#     // Check each particle (naively) to see if it covers this pixel.
#     for (int i = 0; i < numParticles; i++) {
#         Particle p = particles[i];
#         float dx = x - p.position.x;
#         float dy = y - p.position.y;
#         if ((dx * dx + dy * dy) <= (p.radius * p.radius)) {
#             if (frameNumber >= 500) {
#                 // RED after frame 200
#                 framebuffer[pixelIdx + 0] = 255;
#                 framebuffer[pixelIdx + 1] = 0;
#                 framebuffer[pixelIdx + 2] = 0;
#             } else {
#                 // BLUE before frame 200
#                 framebuffer[pixelIdx + 0] = 0;
#                 framebuffer[pixelIdx + 1] = 0;
#                 framebuffer[pixelIdx + 2] = 255;
#             }
#             break;
#         }
#     }
# }
#
# void renderParticles(const Particle* d_particles, int numParticles,
#                      const Obstacle* d_obstacles, int numObstacles,
#                      unsigned char* d_framebuffer, int width, int height, int frameNumber) {
#     dim3 threadsPerBlock(16, 16);
#     dim3 numBlocks((width + 15) / 16, (height + 15) / 16);
#     renderParticlesKernel<<<numBlocks, threadsPerBlock>>>(
#         d_particles, numParticles,
#         d_obstacles, numObstacles,
#         d_framebuffer, width, height, frameNumber);
# }
# Out:
# Overwriting render.cu

# %%
# %%writefile main.cu
# #include "simulation.cuh"
# #include "render.cuh"
# #include "constants.cuh"
# #include "collisions.cuh"
# #include <cuda_runtime.h>
# #include <iostream>
# #include <fstream>
# #include <cstdlib>
#
#
# void saveFramePPM(const char* filename, unsigned char* framebuffer, int width, int height) {
#     std::ofstream ofs(filename, std::ios::binary);
#     if (!ofs) {
#         std::cerr << "Error: Could not open file " << filename << " for writing." << std::endl;
#         return;
#     }
#     // Write the PPM header: P6, width, height, and max color value.
#     ofs << "P6\n" << width << " " << height << "\n255\n";
#     // Write pixel data: for each pixel, write only the first 3 bytes (RGB)
#     for (int i = 0; i < width * height; i++) {
#         ofs.write(reinterpret_cast<char*>(&framebuffer[i * 4]), 3);
#     }
#     ofs.close();
# }
#
# int main() {
#     // Set the number of particles.
#     const int numParticles = 128;
#     size_t particlesSize = numParticles * sizeof(Particle);
#
#     // Allocate and initialize host particle data.
#     Particle *h_particles = new Particle[numParticles];
#     for (int i = 0; i < numParticles; i++) {
#         h_particles[i].position = make_float2(rand() % WINDOW_WIDTH, rand() % WINDOW_HEIGHT);
#         h_particles[i].velocity = make_float2(((rand() % 200) / 100.0f) - 1.0f,
#                                               ((rand() % 200) / 100.0f) - 1.0f);
#         h_particles[i].radius = PARTICLE_RADIUS;
#     }
#
#     Obstacle h_obstacles[] = {
#     { make_float2(400.0f, 300.0f), 40.0f },
#     { make_float2(200.0f, 500.0f), 25.0f }
#     };
#     int numObstacles = sizeof(h_obstacles) / sizeof(Obstacle);
#
#     Obstacle* d_obstacles;
#     cudaMalloc(&d_obstacles, sizeof(h_obstacles));
#     cudaMemcpy(d_obstacles, h_obstacles, sizeof(h_obstacles), cudaMemcpyHostToDevice);
#
#     // Allocate device memory for particles.
#     Particle *d_particles;
#     cudaMalloc(&d_particles, particlesSize);
#     cudaMemcpy(d_particles, h_particles, particlesSize, cudaMemcpyHostToDevice);
#
#     // Allocate device memory for grid arrays.
#     int numCells = GRID_WIDTH * GRID_HEIGHT;
#     int *d_gridCounters, *d_gridIndices;
#     cudaMalloc(&d_gridCounters, numCells * sizeof(int));
#     cudaMalloc(&d_gridIndices, numCells * MAX_PARTICLES_PER_CELL * sizeof(int));
#
#     // Allocate device framebuffer (RGBA) for rendering.
#     int width = WINDOW_WIDTH, height = WINDOW_HEIGHT;
#     size_t framebufferSize = width * height * 4 * sizeof(unsigned char);
#     unsigned char *d_framebuffer;
#     cudaMalloc(&d_framebuffer, framebufferSize);
#
#     // Allocate host memory for the framebuffer.
#     unsigned char *h_framebuffer = new unsigned char[framebufferSize];
#
#     // Simulation loop: Render and save a sequence of frames.
#     const int numFrames = 1000;
#
#     for (int frame = 0; frame < numFrames; frame++) {
#         float deltaTime = 0.016f; // ~60 fps
#
#         // Run one simulation step: integration, grid building, and collision resolution.
#         runSimulationStep(d_particles, numParticles, deltaTime, GRAVITY, d_gridCounters, d_gridIndices, d_obstacles, numObstacles);
#
#         // Render particles into the device framebuffer.
#         renderParticles(d_particles, numParticles,
#                 d_obstacles, numObstacles,
#                 d_framebuffer, width, height, frame);
#
#         // Copy the framebuffer from device to host.
#         cudaMemcpy(h_framebuffer, d_framebuffer, framebufferSize, cudaMemcpyDeviceToHost);
#
#         // Save the current frame as a PPM image.
#         char filename[64];
#         sprintf(filename, "zframe_%03d.ppm", frame);
#         saveFramePPM(filename, h_framebuffer, width, height);
#
#         std::cout << "Saved " << filename << std::endl;
#     }
#
#     // Clean up CUDA memory.
#     cudaFree(d_particles);
#     cudaFree(d_gridCounters);
#     cudaFree(d_gridIndices);
#     cudaFree(d_framebuffer);
#
#     // Clean up host memory.
#     delete[] h_particles;
#     delete[] h_framebuffer;
#
#     return 0;
# }
# Out:
# Overwriting main.cu

# %%
# !nvcc -arch=sm_75 -gencode=arch=compute_75,code=sm_75 main.cu simulation.cu collisions.cu render.cu -o particleSim

# %%
# !./particleSim
# Out:
# Saved zframe_000.ppm
# Saved zframe_001.ppm
# Saved zframe_002.ppm
# Saved zframe_003.ppm
# Saved zframe_004.ppm
# Saved zframe_005.ppm
# Saved zframe_006.ppm
# Saved zframe_007.ppm
# Saved zframe_008.ppm
# Saved zframe_009.ppm
# Saved zframe_010.ppm
# Saved zframe_011.ppm
# Saved zframe_012.ppm
# Saved zframe_013.ppm
# Saved zframe_014.ppm
# Saved zframe_015.ppm
# Saved zframe_016.ppm
# Saved zframe_017.ppm
# Saved zframe_018.ppm
# Saved zframe_019.ppm
# Saved zframe_020.ppm
# Saved zframe_021.ppm
# Saved zframe_022.ppm
# Saved zframe_023.ppm
# Saved zframe_024.ppm
# Saved zframe_025.ppm
# Saved zframe_026.ppm
# Saved zframe_027.ppm
# Saved zframe_028.ppm
# Saved zframe_029.ppm
# Saved zframe_030.ppm
# Saved zframe_031.ppm
# Saved zframe_032.ppm
# Saved zframe_033.ppm
# Saved zframe_034.ppm
# Saved zframe_035.ppm
# Saved zframe_036.ppm
# Saved zframe_037.ppm
# Saved zframe_038.ppm
# Saved zframe_039.ppm
# Saved zframe_040.ppm
# Saved zframe_041.ppm
# Saved zframe_042.ppm
# Saved zframe_043.ppm
# Saved zframe_044.ppm
# Saved zframe_045.ppm
# Saved zframe_046.ppm
# Saved zframe_047.ppm
# Saved zframe_048.ppm
# Saved zframe_049.ppm
# Saved zframe_050.ppm
# Saved zframe_051.ppm
# Saved zframe_052.ppm
# Saved zframe_053.ppm
# Saved zframe_054.ppm
# Saved zframe_055.ppm
# Saved zframe_056.ppm
# Saved zframe_057.ppm
# Saved zframe_058.ppm
# Saved zframe_059.ppm
# Saved zframe_060.ppm
# Saved zframe_061.ppm
# Saved zframe_062.ppm
# Saved zframe_063.ppm
# Saved zframe_064.ppm
# Saved zframe_065.ppm
# Saved zframe_066.ppm
# Saved zframe_067.ppm
# Saved zframe_068.ppm
# Saved zframe_069.ppm
# Saved zframe_070.ppm
# Saved zframe_071.ppm
# Saved zframe_072.ppm
# Saved zframe_073.ppm
# Saved zframe_074.ppm
# Saved zframe_075.ppm
# Saved zframe_076.ppm
# Saved zframe_077.ppm
# Saved zframe_078.ppm
# Saved zframe_079.ppm
# Saved zframe_080.ppm
# Saved zframe_081.ppm
# Saved zframe_082.ppm
# Saved zframe_083.ppm
# Saved zframe_084.ppm
# Saved zframe_085.ppm
# Saved zframe_086.ppm
# Saved zframe_087.ppm
# Saved zframe_846.ppm
# Saved zframe_847.ppm
# Saved zframe_848.ppm
# Saved zframe_849.ppm
# Saved zframe_850.ppm
# Saved zframe_851.ppm
# Saved zframe_852.ppm
# Saved zframe_853.ppm
# Saved zframe_854.ppm
# Saved zframe_855.ppm
# Saved zframe_856.ppm
# Saved zframe_857.ppm
# Saved zframe_858.ppm
# Saved zframe_859.ppm
# Saved zframe_860.ppm
# Saved zframe_861.ppm
# Saved zframe_862.ppm
# Saved zframe_863.ppm
# Saved zframe_864.ppm
# Saved zframe_865.ppm
# Saved zframe_866.ppm
# Saved zframe_867.ppm
# Saved zframe_868.ppm
# Saved zframe_869.ppm
# Saved zframe_870.ppm
# Saved zframe_871.ppm
# Saved zframe_872.ppm
# Saved zframe_873.ppm
# Saved zframe_874.ppm
# Saved zframe_875.ppm
# Saved zframe_876.ppm
# Saved zframe_877.ppm
# Saved zframe_878.ppm
# Saved zframe_879.ppm
# Saved zframe_880.ppm
# Saved zframe_881.ppm
# Saved zframe_882.ppm
# Saved zframe_883.ppm
# Saved zframe_884.ppm
# Saved zframe_885.ppm
# Saved zframe_886.ppm
# Saved zframe_887.ppm
# Saved zframe_888.ppm
# Saved zframe_889.ppm
# Saved zframe_890.ppm
# Saved zframe_891.ppm
# Saved zframe_892.ppm
# Saved zframe_893.ppm
# Saved zframe_894.ppm
# Saved zframe_895.ppm
# Saved zframe_896.ppm
# Saved zframe_897.ppm
# Saved zframe_898.ppm
# Saved zframe_899.ppm
# Saved zframe_900.ppm
# Saved zframe_901.ppm
# Saved zframe_902.ppm
# Saved zframe_903.ppm
# Saved zframe_904.ppm
# Saved zframe_905.ppm
# Saved zframe_906.ppm
# Saved zframe_907.ppm
# Saved zframe_908.ppm
# Saved zframe_909.ppm
# Saved zframe_910.ppm
# Saved zframe_911.ppm
# Saved zframe_912.ppm
# Saved zframe_913.ppm
# Saved zframe_914.ppm
# Saved zframe_915.ppm
# Saved zframe_916.ppm
# Saved zframe_917.ppm
# Saved zframe_918.ppm
# Saved zframe_919.ppm
# Saved zframe_920.ppm
# Saved zframe_921.ppm
# Saved zframe_922.ppm
# Saved zframe_923.ppm
# Saved zframe_924.ppm
# Saved zframe_925.ppm
# Saved zframe_926.ppm
# Saved zframe_927.ppm
# Saved zframe_928.ppm
# Saved zframe_929.ppm
# Saved zframe_930.ppm
# Saved zframe_931.ppm
# Saved zframe_932.ppm
# Saved zframe_933.ppm
# Saved zframe_934.ppm
# Saved zframe_935.ppm
# Saved zframe_936.ppm
# Saved zframe_937.ppm
# Saved zframe_938.ppm
# Saved zframe_939.ppm
# Saved zframe_940.ppm
# Saved zframe_941.ppm
# Saved zframe_942.ppm
# Saved zframe_943.ppm
# Saved zframe_944.ppm
# Saved zframe_945.ppm
# Saved zframe_946.ppm
# Saved zframe_947.ppm
# Saved zframe_948.ppm
# Saved zframe_949.ppm
# Saved zframe_950.ppm
# Saved zframe_951.ppm
# Saved zframe_952.ppm
# Saved zframe_953.ppm
# Saved zframe_954.ppm
# Saved zframe_955.ppm
# Saved zframe_956.ppm
# Saved zframe_957.ppm
# Saved zframe_958.ppm
# Saved zframe_959.ppm
# Saved zframe_960.ppm
# Saved zframe_961.ppm
# Saved zframe_962.ppm
# Saved zframe_963.ppm
# Saved zframe_964.ppm
# Saved zframe_965.ppm
# Saved zframe_966.ppm
# Saved zframe_967.ppm
# Saved zframe_968.ppm
# Saved zframe_969.ppm
# Saved zframe_970.ppm
# Saved zframe_971.ppm
# Saved zframe_972.ppm
# Saved zframe_973.ppm
# Saved zframe_974.ppm
# Saved zframe_975.ppm
# Saved zframe_976.ppm
# Saved zframe_977.ppm
# Saved zframe_978.ppm
# Saved zframe_979.ppm
# Saved zframe_980.ppm
# Saved zframe_981.ppm
# Saved zframe_982.ppm
# Saved zframe_983.ppm
# Saved zframe_984.ppm
# Saved zframe_985.ppm
# Saved zframe_986.ppm
# Saved zframe_987.ppm
# Saved zframe_988.ppm
# Saved zframe_989.ppm
# Saved zframe_990.ppm
# Saved zframe_991.ppm
# Saved zframe_992.ppm
# Saved zframe_993.ppm
# Saved zframe_994.ppm
# Saved zframe_995.ppm
# Saved zframe_996.ppm
# Saved zframe_997.ppm
# Saved zframe_998.ppm
# Saved zframe_999.ppm

# %%
import re, os,sys
import matplotlib.pyplot as plt
from IPython.display import Image, display,clear_output
import time
from PIL import Image as PILImage # import the PIL library

files = os.listdir("/content")
file_names = []
for file_ in files:
    if file_.endswith("ppm"):
      # sys.stdout.write(file_)
      # sys.stdout.flush()
      file_names.append(file_)

# %%
file_names.sort()

# %%
# !pip install imageio
# Out:
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (2.37.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from imageio) (2.0.2)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio) (11.1.0)

# %%
import imageio

frames = []
for file_ in file_names:
  if os.path.exists(file_):
      frames.append(imageio.imread(file_))

# Save as an animated GIF
output_gif = "particle_simulation.gif"
imageio.mimsave(output_gif, frames, duration=0.05)  # 50 ms per frame

print(f"Saved GIF: {output_gif}")
# Out:
# <ipython-input-174-9bb0e8018f34>:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   frames.append(imageio.imread(file_))
# Saved GIF: particle_simulation.gif

# %%
import numpy as np
import imageio

gif = imageio.get_reader("particle_simulation.gif", memtest=False)
differences = []

# Iterate through frames using a for loop and gif.iter_data()
for i, frame in enumerate(gif.iter_data()):
    if i > 0:  # Skip the first frame for comparison
        frame1 = np.array(prev_frame)
        frame2 = np.array(frame)
        diff = np.sum(frame1 != frame2)
        differences.append(diff)
    prev_frame = frame  # Store current frame for next comparison


# Report
diff_count = len(differences)
for i, diff in enumerate(differences):
    print(f"GIF frame {i:03d} → {i+1:03d}: {diff} differing pixels")

if all(d == 0 for d in differences):
    print("\n⚠️ All GIF frames are identical.")
else:
    print("\n✅ The GIF shows motion between frames.")
    print(f"GIF has {diff_count} frames.")
# Out:
# GIF frame 000 → 001: 265 differing pixels
# GIF frame 001 → 002: 99 differing pixels
# GIF frame 002 → 003: 556 differing pixels
# GIF frame 003 → 004: 669 differing pixels
# GIF frame 004 → 005: 1310 differing pixels
# GIF frame 005 → 006: 611 differing pixels
# GIF frame 006 → 007: 1888 differing pixels
# GIF frame 007 → 008: 933 differing pixels
# GIF frame 008 → 009: 1873 differing pixels
# GIF frame 009 → 010: 2043 differing pixels
# GIF frame 010 → 011: 1625 differing pixels
# GIF frame 011 → 012: 1906 differing pixels
# GIF frame 012 → 013: 2230 differing pixels
# GIF frame 013 → 014: 2421 differing pixels
# GIF frame 014 → 015: 2527 differing pixels
# GIF frame 015 → 016: 2710 differing pixels
# GIF frame 016 → 017: 2933 differing pixels
# GIF frame 017 → 018: 3071 differing pixels
# GIF frame 018 → 019: 3113 differing pixels
# GIF frame 019 → 020: 3177 differing pixels
# GIF frame 020 → 021: 3537 differing pixels
# GIF frame 021 → 022: 3487 differing pixels
# GIF frame 022 → 023: 3772 differing pixels
# GIF frame 023 → 024: 3810 differing pixels
# GIF frame 024 → 025: 4017 differing pixels
# GIF frame 025 → 026: 4152 differing pixels
# GIF frame 026 → 027: 4277 differing pixels
# GIF frame 027 → 028: 4418 differing pixels
# GIF frame 028 → 029: 4545 differing pixels
# GIF frame 029 → 030: 4745 differing pixels
# GIF frame 030 → 031: 4889 differing pixels
# GIF frame 031 → 032: 4995 differing pixels
# GIF frame 032 → 033: 5110 differing pixels
# GIF frame 033 → 034: 5284 differing pixels
# GIF frame 034 → 035: 5388 differing pixels
# GIF frame 035 → 036: 5523 differing pixels
# GIF frame 036 → 037: 5625 differing pixels
# GIF frame 037 → 038: 5812 differing pixels
# GIF frame 038 → 039: 5899 differing pixels
# GIF frame 039 → 040: 6052 differing pixels
# GIF frame 040 → 041: 6209 differing pixels
# GIF frame 041 → 042: 6281 differing pixels
# GIF frame 042 → 043: 6435 differing pixels
# GIF frame 043 → 044: 6534 differing pixels
# GIF frame 044 → 045: 6609 differing pixels
# GIF frame 045 → 046: 6776 differing pixels
# GIF frame 046 → 047: 6860 differing pixels
# GIF frame 047 → 048: 7034 differing pixels
# GIF frame 048 → 049: 7053 differing pixels
# GIF frame 049 → 050: 7179 differing pixels
# GIF frame 050 → 051: 7231 differing pixels
# GIF frame 051 → 052: 7411 differing pixels
# GIF frame 052 → 053: 7401 differing pixels
# GIF frame 053 → 054: 7501 differing pixels
# GIF frame 054 → 055: 7590 differing pixels
# GIF frame 055 → 056: 7655 differing pixels
# GIF frame 056 → 057: 7634 differing pixels
# GIF frame 057 → 058: 7860 differing pixels
# GIF frame 058 → 059: 7891 differing pixels
# GIF frame 059 → 060: 7927 differing pixels
# GIF frame 060 → 061: 8003 differing pixels
# GIF frame 061 → 062: 8129 differing pixels
# GIF frame 062 → 063: 8153 differing pixels
# GIF frame 063 → 064: 8119 differing pixels
# GIF frame 064 → 065: 8239 differing pixels
# GIF frame 065 → 066: 8271 differing pixels
# GIF frame 066 → 067: 8399 differing pixels
# GIF frame 067 → 068: 8415 differing pixels
# GIF frame 068 → 069: 8582 differing pixels
# GIF frame 069 → 070: 8414 differing pixels
# GIF frame 070 → 071: 8600 differing pixels
# GIF frame 071 → 072: 8702 differing pixels
# GIF frame 072 → 073: 8692 differing pixels
# GIF frame 073 → 074: 8908 differing pixels
# GIF frame 074 → 075: 8862 differing pixels
# GIF frame 075 → 076: 8984 differing pixels
# GIF frame 076 → 077: 8946 differing pixels
# GIF frame 077 → 078: 8893 differing pixels
# GIF frame 078 → 079: 8981 differing pixels
# GIF frame 079 → 080: 9025 differing pixels
# GIF frame 080 → 081: 9217 differing pixels
# GIF frame 081 → 082: 9247 differing pixels
# GIF frame 082 → 083: 9170 differing pixels
# GIF frame 083 → 084: 9138 differing pixels
# GIF frame 084 → 085: 9329 differing pixels
# GIF frame 085 → 086: 9420 differing pixels
# GIF frame 086 → 087: 9394 differing pixels
# GIF frame 087 → 088: 9409 differing pixels
# GIF frame 088 → 089: 9276 differing pixels
# GIF frame 089 → 090: 9249 differing pixels
# GIF frame 090 → 091: 9468 differing pixels
# GIF frame 091 → 092: 9432 differing pixels
# GIF frame 092 → 093: 9488 differing pixels
# GIF frame 093 → 094: 9470 differing pixels
# GIF frame 094 → 095: 9473 differing pixels
# GIF frame 095 → 096: 9488 differing pixels
# GIF frame 096 → 097: 9336 differing pixels
# GIF frame 097 → 098: 9761 differing pixels
# GIF frame 098 → 099: 9738 differing pixels
# GIF frame 099 → 100: 9765 differing pixels
# GIF frame 100 → 101: 9834 differing pixels
# GIF frame 101 → 102: 9808 differing pixels
# GIF frame 102 → 103: 9806 differing pixels
# GIF frame 103 → 104: 9805 differing pixels
# GIF frame 104 → 105: 9525 differing pixels
# GIF frame 105 → 106: 9694 differing pixels
# GIF frame 106 → 107: 9583 differing pixels
# GIF frame 107 → 108: 9594 differing pixels
# GIF frame 108 → 109: 9563 differing pixels
# GIF frame 109 → 110: 9433 differing pixels
# GIF frame 110 → 111: 9639 differing pixels
# GIF frame 111 → 112: 9473 differing pixels
# GIF frame 112 → 113: 9526 differing pixels
# GIF frame 113 → 114: 9579 differing pixels
# GIF frame 114 → 115: 9565 differing pixels
# GIF frame 115 → 116: 9383 differing pixels
# GIF frame 116 → 117: 9407 differing pixels
# GIF frame 117 → 118: 9404 differing pixels
# GIF frame 118 → 119: 9362 differing pixels
# GIF frame 119 → 120: 9192 differing pixels
# GIF frame 120 → 121: 9203 differing pixels
# GIF frame 121 → 122: 9119 differing pixels
# GIF frame 122 → 123: 8939 differing pixels
# GIF frame 123 → 124: 8959 differing pixels
# GIF frame 124 → 125: 8822 differing pixels
# GIF frame 125 → 126: 8714 differing pixels
# GIF frame 126 → 127: 8662 differing pixels
# GIF frame 127 → 128: 8662 differing pixels
# GIF frame 128 → 129: 8682 differing pixels
# GIF frame 129 → 130: 8634 differing pixels
# GIF frame 130 → 131: 8559 differing pixels
# GIF frame 131 → 132: 8438 differing pixels
# GIF frame 132 → 133: 8350 differing pixels
# GIF frame 133 → 134: 8209 differing pixels
# GIF frame 134 → 135: 8321 differing pixels
# GIF frame 135 → 136: 8240 differing pixels
# GIF frame 136 → 137: 8228 differing pixels
# GIF frame 137 → 138: 8187 differing pixels
# GIF frame 138 → 139: 8011 differing pixels
# GIF frame 139 → 140: 8029 differing pixels
# GIF frame 140 → 141: 8072 differing pixels
# GIF frame 141 → 142: 7930 differing pixels
# GIF frame 142 → 143: 7942 differing pixels
# GIF frame 143 → 144: 7777 differing pixels
# GIF frame 144 → 145: 7818 differing pixels
# GIF frame 145 → 146: 7635 differing pixels
# GIF frame 146 → 147: 7474 differing pixels
# GIF frame 147 → 148: 7583 differing pixels
# GIF frame 148 → 149: 7534 differing pixels
# GIF frame 149 → 150: 7386 differing pixels
# GIF frame 150 → 151: 7247 differing pixels
# GIF frame 151 → 152: 7225 differing pixels
# GIF frame 152 → 153: 7077 differing pixels
# GIF frame 153 → 154: 7010 differing pixels
# GIF frame 154 → 155: 7010 differing pixels
# GIF frame 155 → 156: 6861 differing pixels
# GIF frame 156 → 157: 6913 differing pixels
# GIF frame 157 → 158: 6708 differing pixels
# GIF frame 158 → 159: 6860 differing pixels
# GIF frame 159 → 160: 6728 differing pixels
# GIF frame 160 → 161: 6579 differing pixels
# GIF frame 161 → 162: 6529 differing pixels
# GIF frame 162 → 163: 6492 differing pixels
# GIF frame 163 → 164: 6383 differing pixels
# GIF frame 164 → 165: 6224 differing pixels
# GIF frame 165 → 166: 6174 differing pixels
# GIF frame 166 → 167: 6199 differing pixels
# GIF frame 167 → 168: 6157 differing pixels
# GIF frame 168 → 169: 6131 differing pixels
# GIF frame 169 → 170: 5997 differing pixels
# GIF frame 170 → 171: 5866 differing pixels
# GIF frame 171 → 172: 5827 differing pixels
# GIF frame 172 → 173: 5834 differing pixels
# GIF frame 173 → 174: 5776 differing pixels
# GIF frame 174 → 175: 5745 differing pixels
# GIF frame 175 → 176: 5682 differing pixels
# GIF frame 176 → 177: 5661 differing pixels
# GIF frame 177 → 178: 5721 differing pixels
# GIF frame 178 → 179: 5574 differing pixels
# GIF frame 179 → 180: 5607 differing pixels
# GIF frame 180 → 181: 5542 differing pixels
# GIF frame 181 → 182: 5528 differing pixels
# GIF frame 182 → 183: 5464 differing pixels
# GIF frame 183 → 184: 5496 differing pixels
# GIF frame 184 → 185: 5501 differing pixels
# GIF frame 185 → 186: 5345 differing pixels
# GIF frame 186 → 187: 5482 differing pixels
# GIF frame 187 → 188: 5267 differing pixels
# GIF frame 188 → 189: 5407 differing pixels
# GIF frame 189 → 190: 5369 differing pixels
# GIF frame 190 → 191: 5279 differing pixels
# GIF frame 191 → 192: 5319 differing pixels
# GIF frame 192 → 193: 5346 differing pixels
# GIF frame 193 → 194: 5261 differing pixels
# GIF frame 194 → 195: 5296 differing pixels
# GIF frame 195 → 196: 5371 differing pixels
# GIF frame 196 → 197: 5273 differing pixels
# GIF frame 197 → 198: 5307 differing pixels
# GIF frame 198 → 199: 5343 differing pixels
# GIF frame 199 → 200: 5385 differing pixels
# GIF frame 200 → 201: 5350 differing pixels
# GIF frame 201 → 202: 5456 differing pixels
# GIF frame 202 → 203: 5415 differing pixels
# GIF frame 203 → 204: 5499 differing pixels
# GIF frame 204 → 205: 5534 differing pixels
# GIF frame 205 → 206: 5404 differing pixels
# GIF frame 206 → 207: 5506 differing pixels
# GIF frame 207 → 208: 5543 differing pixels
# GIF frame 208 → 209: 5512 differing pixels
# GIF frame 209 → 210: 5687 differing pixels
# GIF frame 210 → 211: 5663 differing pixels
# GIF frame 211 → 212: 5521 differing pixels
# GIF frame 212 → 213: 5655 differing pixels
# GIF frame 213 → 214: 5667 differing pixels
# GIF frame 214 → 215: 5553 differing pixels
# GIF frame 215 → 216: 5642 differing pixels
# GIF frame 216 → 217: 5619 differing pixels
# GIF frame 217 → 218: 5611 differing pixels
# GIF frame 218 → 219: 5643 differing pixels
# GIF frame 219 → 220: 5682 differing pixels
# GIF frame 220 → 221: 5716 differing pixels
# GIF frame 221 → 222: 5634 differing pixels
# GIF frame 222 → 223: 5696 differing pixels
# GIF frame 223 → 224: 5655 differing pixels
# GIF frame 224 → 225: 5713 differing pixels
# GIF frame 225 → 226: 5803 differing pixels
# GIF frame 226 → 227: 5677 differing pixels
# GIF frame 227 → 228: 5774 differing pixels
# GIF frame 228 → 229: 5709 differing pixels
# GIF frame 229 → 230: 5859 differing pixels
# GIF frame 230 → 231: 5772 differing pixels
# GIF frame 231 → 232: 5582 differing pixels
# GIF frame 232 → 233: 5799 differing pixels
# GIF frame 233 → 234: 5717 differing pixels
# GIF frame 234 → 235: 5900 differing pixels
# GIF frame 235 → 236: 5840 differing pixels
# GIF frame 236 → 237: 5923 differing pixels
# GIF frame 237 → 238: 5904 differing pixels
# GIF frame 238 → 239: 5796 differing pixels
# GIF frame 239 → 240: 5888 differing pixels
# GIF frame 240 → 241: 5958 differing pixels
# GIF frame 241 → 242: 5927 differing pixels
# GIF frame 242 → 243: 6014 differing pixels
# GIF frame 243 → 244: 6018 differing pixels
# GIF frame 244 → 245: 5971 differing pixels
# GIF frame 245 → 246: 5998 differing pixels
# GIF frame 246 → 247: 6035 differing pixels
# GIF frame 247 → 248: 6010 differing pixels
# GIF frame 248 → 249: 5889 differing pixels
# GIF frame 249 → 250: 6018 differing pixels
# GIF frame 250 → 251: 5870 differing pixels
# GIF frame 251 → 252: 5865 differing pixels
# GIF frame 252 → 253: 5983 differing pixels
# GIF frame 253 → 254: 5780 differing pixels
# GIF frame 254 → 255: 5874 differing pixels
# GIF frame 255 → 256: 5984 differing pixels
# GIF frame 256 → 257: 5885 differing pixels
# GIF frame 257 → 258: 5790 differing pixels
# GIF frame 258 → 259: 5786 differing pixels
# GIF frame 259 → 260: 5771 differing pixels
# GIF frame 260 → 261: 5662 differing pixels
# GIF frame 261 → 262: 5867 differing pixels
# GIF frame 262 → 263: 5810 differing pixels
# GIF frame 263 → 264: 5941 differing pixels
# GIF frame 264 → 265: 5817 differing pixels
# GIF frame 265 → 266: 5721 differing pixels
# GIF frame 266 → 267: 5847 differing pixels
# GIF frame 267 → 268: 5855 differing pixels
# GIF frame 268 → 269: 5774 differing pixels
# GIF frame 269 → 270: 5846 differing pixels
# GIF frame 270 → 271: 5884 differing pixels
# GIF frame 271 → 272: 5831 differing pixels
# GIF frame 272 → 273: 5860 differing pixels
# GIF frame 273 → 274: 5892 differing pixels
# GIF frame 274 → 275: 5852 differing pixels
# GIF frame 275 → 276: 5862 differing pixels
# GIF frame 276 → 277: 5918 differing pixels
# GIF frame 277 → 278: 5687 differing pixels
# GIF frame 278 → 279: 5873 differing pixels
# GIF frame 279 → 280: 5943 differing pixels
# GIF frame 280 → 281: 5950 differing pixels
# GIF frame 281 → 282: 5724 differing pixels
# GIF frame 282 → 283: 5930 differing pixels
# GIF frame 283 → 284: 5861 differing pixels
# GIF frame 284 → 285: 5984 differing pixels
# GIF frame 285 → 286: 5891 differing pixels
# GIF frame 286 → 287: 5770 differing pixels
# GIF frame 287 → 288: 5876 differing pixels
# GIF frame 288 → 289: 5799 differing pixels
# GIF frame 289 → 290: 5658 differing pixels
# GIF frame 290 → 291: 5833 differing pixels
# GIF frame 291 → 292: 5843 differing pixels
# GIF frame 292 → 293: 5815 differing pixels
# GIF frame 293 → 294: 5894 differing pixels
# GIF frame 294 → 295: 5719 differing pixels
# GIF frame 295 → 296: 5749 differing pixels
# GIF frame 296 → 297: 5721 differing pixels
# GIF frame 297 → 298: 5587 differing pixels
# GIF frame 298 → 299: 5646 differing pixels
# GIF frame 299 → 300: 5697 differing pixels
# GIF frame 300 → 301: 5655 differing pixels
# GIF frame 301 → 302: 5574 differing pixels
# GIF frame 302 → 303: 5580 differing pixels
# GIF frame 303 → 304: 5582 differing pixels
# GIF frame 304 → 305: 5368 differing pixels
# GIF frame 305 → 306: 5452 differing pixels
# GIF frame 306 → 307: 5333 differing pixels
# GIF frame 307 → 308: 5519 differing pixels
# GIF frame 308 → 309: 5393 differing pixels
# GIF frame 309 → 310: 5245 differing pixels
# GIF frame 310 → 311: 5254 differing pixels
# GIF frame 311 → 312: 5207 differing pixels
# GIF frame 312 → 313: 5147 differing pixels
# GIF frame 313 → 314: 5027 differing pixels
# GIF frame 314 → 315: 4912 differing pixels
# GIF frame 315 → 316: 4892 differing pixels
# GIF frame 316 → 317: 4886 differing pixels
# GIF frame 317 → 318: 4865 differing pixels
# GIF frame 318 → 319: 4962 differing pixels
# GIF frame 319 → 320: 4895 differing pixels
# GIF frame 320 → 321: 4802 differing pixels
# GIF frame 321 → 322: 4760 differing pixels
# GIF frame 322 → 323: 4810 differing pixels
# GIF frame 323 → 324: 4824 differing pixels
# GIF frame 324 → 325: 4747 differing pixels
# GIF frame 325 → 326: 4744 differing pixels
# GIF frame 326 → 327: 4708 differing pixels
# GIF frame 327 → 328: 4692 differing pixels
# GIF frame 328 → 329: 4609 differing pixels
# GIF frame 329 → 330: 4599 differing pixels
# GIF frame 330 → 331: 4580 differing pixels
# GIF frame 331 → 332: 4623 differing pixels
# GIF frame 332 → 333: 4638 differing pixels
# GIF frame 333 → 334: 4522 differing pixels
# GIF frame 334 → 335: 4533 differing pixels
# GIF frame 335 → 336: 4428 differing pixels
# GIF frame 336 → 337: 4415 differing pixels
# GIF frame 337 → 338: 4421 differing pixels
# GIF frame 338 → 339: 4381 differing pixels
# GIF frame 339 → 340: 4460 differing pixels
# GIF frame 340 → 341: 4403 differing pixels
# GIF frame 341 → 342: 4384 differing pixels
# GIF frame 342 → 343: 4318 differing pixels
# GIF frame 343 → 344: 4351 differing pixels
# GIF frame 344 → 345: 4292 differing pixels
# GIF frame 345 → 346: 4312 differing pixels
# GIF frame 346 → 347: 4345 differing pixels
# GIF frame 347 → 348: 4309 differing pixels
# GIF frame 348 → 349: 4307 differing pixels
# GIF frame 349 → 350: 4289 differing pixels
# GIF frame 350 → 351: 4406 differing pixels
# GIF frame 351 → 352: 4252 differing pixels
# GIF frame 352 → 353: 4216 differing pixels
# GIF frame 353 → 354: 4115 differing pixels
# GIF frame 354 → 355: 4325 differing pixels
# GIF frame 355 → 356: 4233 differing pixels
# GIF frame 356 → 357: 4221 differing pixels
# GIF frame 357 → 358: 4202 differing pixels
# GIF frame 358 → 359: 4181 differing pixels
# GIF frame 359 → 360: 4230 differing pixels
# GIF frame 360 → 361: 4464 differing pixels
# GIF frame 361 → 362: 4334 differing pixels
# GIF frame 362 → 363: 4291 differing pixels
# GIF frame 363 → 364: 4376 differing pixels
# GIF frame 364 → 365: 4308 differing pixels
# GIF frame 365 → 366: 4420 differing pixels
# GIF frame 366 → 367: 4262 differing pixels
# GIF frame 367 → 368: 4357 differing pixels
# GIF frame 368 → 369: 4329 differing pixels
# GIF frame 369 → 370: 4214 differing pixels
# GIF frame 370 → 371: 4372 differing pixels
# GIF frame 371 → 372: 4268 differing pixels
# GIF frame 372 → 373: 4299 differing pixels
# GIF frame 373 → 374: 4251 differing pixels
# GIF frame 374 → 375: 4195 differing pixels
# GIF frame 375 → 376: 4181 differing pixels
# GIF frame 376 → 377: 4224 differing pixels
# GIF frame 377 → 378: 4223 differing pixels
# GIF frame 378 → 379: 4126 differing pixels
# GIF frame 379 → 380: 4121 differing pixels
# GIF frame 380 → 381: 4153 differing pixels
# GIF frame 381 → 382: 4025 differing pixels
# GIF frame 382 → 383: 4142 differing pixels
# GIF frame 383 → 384: 4130 differing pixels
# GIF frame 384 → 385: 4144 differing pixels
# GIF frame 385 → 386: 4110 differing pixels
# GIF frame 386 → 387: 4064 differing pixels
# GIF frame 387 → 388: 4044 differing pixels
# GIF frame 388 → 389: 4123 differing pixels
# GIF frame 389 → 390: 4114 differing pixels
# GIF frame 390 → 391: 4010 differing pixels
# GIF frame 391 → 392: 4055 differing pixels
# GIF frame 392 → 393: 4010 differing pixels
# GIF frame 393 → 394: 4032 differing pixels
# GIF frame 394 → 395: 4033 differing pixels
# GIF frame 395 → 396: 4026 differing pixels
# GIF frame 396 → 397: 3914 differing pixels
# GIF frame 397 → 398: 4009 differing pixels
# GIF frame 398 → 399: 3920 differing pixels
# GIF frame 399 → 400: 4025 differing pixels
# GIF frame 400 → 401: 3952 differing pixels
# GIF frame 401 → 402: 3961 differing pixels
# GIF frame 402 → 403: 3900 differing pixels
# GIF frame 403 → 404: 4007 differing pixels
# GIF frame 404 → 405: 4039 differing pixels
# GIF frame 405 → 406: 3997 differing pixels
# GIF frame 406 → 407: 3895 differing pixels
# GIF frame 407 → 408: 3895 differing pixels
# GIF frame 408 → 409: 3964 differing pixels
# GIF frame 409 → 410: 3846 differing pixels
# GIF frame 410 → 411: 4061 differing pixels
# GIF frame 411 → 412: 4026 differing pixels
# GIF frame 412 → 413: 3923 differing pixels
# GIF frame 413 → 414: 3848 differing pixels
# GIF frame 414 → 415: 3880 differing pixels
# GIF frame 415 → 416: 3861 differing pixels
# GIF frame 416 → 417: 3991 differing pixels
# GIF frame 417 → 418: 3893 differing pixels
# GIF frame 418 → 419: 3843 differing pixels
# GIF frame 419 → 420: 3836 differing pixels
# GIF frame 420 → 421: 3874 differing pixels
# GIF frame 421 → 422: 3823 differing pixels
# GIF frame 422 → 423: 3815 differing pixels
# GIF frame 423 → 424: 3819 differing pixels
# GIF frame 424 → 425: 3743 differing pixels
# GIF frame 425 → 426: 3720 differing pixels
# GIF frame 426 → 427: 3688 differing pixels
# GIF frame 427 → 428: 3782 differing pixels
# GIF frame 428 → 429: 3695 differing pixels
# GIF frame 429 → 430: 3703 differing pixels
# GIF frame 430 → 431: 3547 differing pixels
# GIF frame 431 → 432: 3506 differing pixels
# GIF frame 432 → 433: 3608 differing pixels
# GIF frame 433 → 434: 3411 differing pixels
# GIF frame 434 → 435: 3499 differing pixels
# GIF frame 435 → 436: 3448 differing pixels
# GIF frame 436 → 437: 3402 differing pixels
# GIF frame 437 → 438: 3453 differing pixels
# GIF frame 438 → 439: 3402 differing pixels
# GIF frame 439 → 440: 3348 differing pixels
# GIF frame 440 → 441: 3388 differing pixels
# GIF frame 441 → 442: 3384 differing pixels
# GIF frame 442 → 443: 3346 differing pixels
# GIF frame 443 → 444: 3467 differing pixels
# GIF frame 444 → 445: 3376 differing pixels
# GIF frame 445 → 446: 3445 differing pixels
# GIF frame 446 → 447: 3350 differing pixels
# GIF frame 447 → 448: 3461 differing pixels
# GIF frame 448 → 449: 3365 differing pixels
# GIF frame 449 → 450: 3418 differing pixels
# GIF frame 450 → 451: 3312 differing pixels
# GIF frame 451 → 452: 3327 differing pixels
# GIF frame 452 → 453: 3325 differing pixels
# GIF frame 453 → 454: 3322 differing pixels
# GIF frame 454 → 455: 3186 differing pixels
# GIF frame 455 → 456: 3217 differing pixels
# GIF frame 456 → 457: 3251 differing pixels
# GIF frame 457 → 458: 3247 differing pixels
# GIF frame 458 → 459: 3214 differing pixels
# GIF frame 459 → 460: 3141 differing pixels
# GIF frame 460 → 461: 3204 differing pixels
# GIF frame 461 → 462: 3051 differing pixels
# GIF frame 462 → 463: 3149 differing pixels
# GIF frame 463 → 464: 3135 differing pixels
# GIF frame 464 → 465: 3035 differing pixels
# GIF frame 465 → 466: 3074 differing pixels
# GIF frame 466 → 467: 3039 differing pixels
# GIF frame 467 → 468: 2971 differing pixels
# GIF frame 468 → 469: 3037 differing pixels
# GIF frame 469 → 470: 3000 differing pixels
# GIF frame 470 → 471: 2941 differing pixels
# GIF frame 471 → 472: 2951 differing pixels
# GIF frame 472 → 473: 2966 differing pixels
# GIF frame 473 → 474: 2954 differing pixels
# GIF frame 474 → 475: 2952 differing pixels
# GIF frame 475 → 476: 2832 differing pixels
# GIF frame 476 → 477: 2896 differing pixels
# GIF frame 477 → 478: 2971 differing pixels
# GIF frame 478 → 479: 2874 differing pixels
# GIF frame 479 → 480: 2909 differing pixels
# GIF frame 480 → 481: 2951 differing pixels
# GIF frame 481 → 482: 2829 differing pixels
# GIF frame 482 → 483: 2886 differing pixels
# GIF frame 483 → 484: 2873 differing pixels
# GIF frame 484 → 485: 2888 differing pixels
# GIF frame 485 → 486: 2879 differing pixels
# GIF frame 486 → 487: 2907 differing pixels
# GIF frame 487 → 488: 2837 differing pixels
# GIF frame 488 → 489: 2900 differing pixels
# GIF frame 489 → 490: 2890 differing pixels
# GIF frame 490 → 491: 2886 differing pixels
# GIF frame 491 → 492: 2873 differing pixels
# GIF frame 492 → 493: 2878 differing pixels
# GIF frame 493 → 494: 2894 differing pixels
# GIF frame 494 → 495: 2916 differing pixels
# GIF frame 495 → 496: 2860 differing pixels
# GIF frame 496 → 497: 2852 differing pixels
# GIF frame 497 → 498: 2795 differing pixels
# GIF frame 498 → 499: 2882 differing pixels
# GIF frame 499 → 500: 20011 differing pixels
# GIF frame 500 → 501: 2825 differing pixels
# GIF frame 501 → 502: 2902 differing pixels
# GIF frame 502 → 503: 2938 differing pixels
# GIF frame 503 → 504: 2830 differing pixels
# GIF frame 504 → 505: 2811 differing pixels
# GIF frame 505 → 506: 2756 differing pixels
# GIF frame 506 → 507: 2743 differing pixels
# GIF frame 507 → 508: 2627 differing pixels
# GIF frame 508 → 509: 2607 differing pixels
# GIF frame 509 → 510: 2567 differing pixels
# GIF frame 510 → 511: 2519 differing pixels
# GIF frame 511 → 512: 2513 differing pixels
# GIF frame 512 → 513: 2485 differing pixels
# GIF frame 513 → 514: 2556 differing pixels
# GIF frame 514 → 515: 2454 differing pixels
# GIF frame 515 → 516: 2370 differing pixels
# GIF frame 516 → 517: 2453 differing pixels
# GIF frame 517 → 518: 2344 differing pixels
# GIF frame 518 → 519: 2318 differing pixels
# GIF frame 519 → 520: 2421 differing pixels
# GIF frame 520 → 521: 2396 differing pixels
# GIF frame 521 → 522: 2339 differing pixels
# GIF frame 522 → 523: 2282 differing pixels
# GIF frame 523 → 524: 2258 differing pixels
# GIF frame 524 → 525: 2386 differing pixels
# GIF frame 525 → 526: 2306 differing pixels
# GIF frame 526 → 527: 2312 differing pixels
# GIF frame 527 → 528: 2277 differing pixels
# GIF frame 528 → 529: 2341 differing pixels
# GIF frame 529 → 530: 2283 differing pixels
# GIF frame 530 → 531: 2266 differing pixels
# GIF frame 531 → 532: 2296 differing pixels
# GIF frame 532 → 533: 2245 differing pixels
# GIF frame 533 → 534: 2241 differing pixels
# GIF frame 534 → 535: 2191 differing pixels
# GIF frame 535 → 536: 2242 differing pixels
# GIF frame 536 → 537: 2209 differing pixels
# GIF frame 537 → 538: 2242 differing pixels
# GIF frame 538 → 539: 2144 differing pixels
# GIF frame 539 → 540: 2241 differing pixels
# GIF frame 540 → 541: 2221 differing pixels
# GIF frame 541 → 542: 2138 differing pixels
# GIF frame 542 → 543: 2141 differing pixels
# GIF frame 543 → 544: 2121 differing pixels
# GIF frame 544 → 545: 2122 differing pixels
# GIF frame 545 → 546: 2216 differing pixels
# GIF frame 546 → 547: 2079 differing pixels
# GIF frame 547 → 548: 2064 differing pixels
# GIF frame 548 → 549: 2074 differing pixels
# GIF frame 549 → 550: 2136 differing pixels
# GIF frame 550 → 551: 2218 differing pixels
# GIF frame 551 → 552: 1991 differing pixels
# GIF frame 552 → 553: 2080 differing pixels
# GIF frame 553 → 554: 2134 differing pixels
# GIF frame 554 → 555: 2120 differing pixels
# GIF frame 555 → 556: 2065 differing pixels
# GIF frame 556 → 557: 2132 differing pixels
# GIF frame 557 → 558: 2173 differing pixels
# GIF frame 558 → 559: 2157 differing pixels
# GIF frame 559 → 560: 2166 differing pixels
# GIF frame 560 → 561: 2141 differing pixels
# GIF frame 561 → 562: 2168 differing pixels
# GIF frame 562 → 563: 2060 differing pixels
# GIF frame 563 → 564: 2110 differing pixels
# GIF frame 564 → 565: 1998 differing pixels
# GIF frame 565 → 566: 2074 differing pixels
# GIF frame 566 → 567: 2032 differing pixels
# GIF frame 567 → 568: 1989 differing pixels
# GIF frame 568 → 569: 2008 differing pixels
# GIF frame 569 → 570: 1968 differing pixels
# GIF frame 570 → 571: 2039 differing pixels
# GIF frame 571 → 572: 1953 differing pixels
# GIF frame 572 → 573: 1941 differing pixels
# GIF frame 573 → 574: 1915 differing pixels
# GIF frame 574 → 575: 2028 differing pixels
# GIF frame 575 → 576: 1944 differing pixels
# GIF frame 576 → 577: 1971 differing pixels
# GIF frame 577 → 578: 1895 differing pixels
# GIF frame 578 → 579: 1979 differing pixels
# GIF frame 579 → 580: 1863 differing pixels
# GIF frame 580 → 581: 1869 differing pixels
# GIF frame 581 → 582: 1922 differing pixels
# GIF frame 582 → 583: 1856 differing pixels
# GIF frame 583 → 584: 1856 differing pixels
# GIF frame 584 → 585: 1917 differing pixels
# GIF frame 585 → 586: 1833 differing pixels
# GIF frame 586 → 587: 1956 differing pixels
# GIF frame 587 → 588: 1950 differing pixels
# GIF frame 588 → 589: 1842 differing pixels
# GIF frame 589 → 590: 1863 differing pixels
# GIF frame 590 → 591: 1837 differing pixels
# GIF frame 591 → 592: 1839 differing pixels
# GIF frame 592 → 593: 1913 differing pixels
# GIF frame 593 → 594: 1856 differing pixels
# GIF frame 594 → 595: 1894 differing pixels
# GIF frame 595 → 596: 1765 differing pixels
# GIF frame 596 → 597: 1853 differing pixels
# GIF frame 597 → 598: 1741 differing pixels
# GIF frame 598 → 599: 1767 differing pixels
# GIF frame 599 → 600: 1768 differing pixels
# GIF frame 600 → 601: 1678 differing pixels
# GIF frame 601 → 602: 1694 differing pixels
# GIF frame 602 → 603: 1611 differing pixels
# GIF frame 603 → 604: 1636 differing pixels
# GIF frame 604 → 605: 1654 differing pixels
# GIF frame 605 → 606: 1596 differing pixels
# GIF frame 606 → 607: 1670 differing pixels
# GIF frame 607 → 608: 1628 differing pixels
# GIF frame 608 → 609: 1514 differing pixels
# GIF frame 609 → 610: 1620 differing pixels
# GIF frame 610 → 611: 1568 differing pixels
# GIF frame 611 → 612: 1603 differing pixels
# GIF frame 612 → 613: 1562 differing pixels
# GIF frame 613 → 614: 1581 differing pixels
# GIF frame 614 → 615: 1558 differing pixels
# GIF frame 615 → 616: 1591 differing pixels
# GIF frame 616 → 617: 1539 differing pixels
# GIF frame 617 → 618: 1616 differing pixels
# GIF frame 618 → 619: 1518 differing pixels
# GIF frame 619 → 620: 1534 differing pixels
# GIF frame 620 → 621: 1419 differing pixels
# GIF frame 621 → 622: 1479 differing pixels
# GIF frame 622 → 623: 1384 differing pixels
# GIF frame 623 → 624: 1509 differing pixels
# GIF frame 624 → 625: 1465 differing pixels
# GIF frame 625 → 626: 1485 differing pixels
# GIF frame 626 → 627: 1468 differing pixels
# GIF frame 627 → 628: 1458 differing pixels
# GIF frame 628 → 629: 1467 differing pixels
# GIF frame 629 → 630: 1482 differing pixels
# GIF frame 630 → 631: 1369 differing pixels
# GIF frame 631 → 632: 1474 differing pixels
# GIF frame 632 → 633: 1514 differing pixels
# GIF frame 633 → 634: 1494 differing pixels
# GIF frame 634 → 635: 1510 differing pixels
# GIF frame 635 → 636: 1539 differing pixels
# GIF frame 636 → 637: 1518 differing pixels
# GIF frame 637 → 638: 1434 differing pixels
# GIF frame 638 → 639: 1525 differing pixels
# GIF frame 639 → 640: 1508 differing pixels
# GIF frame 640 → 641: 1412 differing pixels
# GIF frame 641 → 642: 1409 differing pixels
# GIF frame 642 → 643: 1413 differing pixels
# GIF frame 643 → 644: 1419 differing pixels
# GIF frame 644 → 645: 1420 differing pixels
# GIF frame 645 → 646: 1381 differing pixels
# GIF frame 646 → 647: 1357 differing pixels
# GIF frame 647 → 648: 1326 differing pixels
# GIF frame 648 → 649: 1241 differing pixels
# GIF frame 649 → 650: 1275 differing pixels
# GIF frame 650 → 651: 1299 differing pixels
# GIF frame 651 → 652: 1213 differing pixels
# GIF frame 652 → 653: 1282 differing pixels
# GIF frame 653 → 654: 1185 differing pixels
# GIF frame 654 → 655: 1248 differing pixels
# GIF frame 655 → 656: 1171 differing pixels
# GIF frame 656 → 657: 1273 differing pixels
# GIF frame 657 → 658: 1207 differing pixels
# GIF frame 658 → 659: 1174 differing pixels
# GIF frame 659 → 660: 1212 differing pixels
# GIF frame 660 → 661: 1150 differing pixels
# GIF frame 661 → 662: 1130 differing pixels
# GIF frame 662 → 663: 1184 differing pixels
# GIF frame 663 → 664: 1212 differing pixels
# GIF frame 664 → 665: 1164 differing pixels
# GIF frame 665 → 666: 1103 differing pixels
# GIF frame 666 → 667: 1247 differing pixels
# GIF frame 667 → 668: 1143 differing pixels
# GIF frame 668 → 669: 1086 differing pixels
# GIF frame 669 → 670: 1192 differing pixels
# GIF frame 670 → 671: 1148 differing pixels
# GIF frame 671 → 672: 1156 differing pixels
# GIF frame 672 → 673: 1166 differing pixels
# GIF frame 673 → 674: 1203 differing pixels
# GIF frame 674 → 675: 1135 differing pixels
# GIF frame 675 → 676: 1188 differing pixels
# GIF frame 676 → 677: 1152 differing pixels
# GIF frame 677 → 678: 1129 differing pixels
# GIF frame 678 → 679: 1112 differing pixels
# GIF frame 679 → 680: 1096 differing pixels
# GIF frame 680 → 681: 1161 differing pixels
# GIF frame 681 → 682: 1135 differing pixels
# GIF frame 682 → 683: 1076 differing pixels
# GIF frame 683 → 684: 1088 differing pixels
# GIF frame 684 → 685: 1144 differing pixels
# GIF frame 685 → 686: 1096 differing pixels
# GIF frame 686 → 687: 1053 differing pixels
# GIF frame 687 → 688: 1104 differing pixels
# GIF frame 688 → 689: 1074 differing pixels
# GIF frame 689 → 690: 1056 differing pixels
# GIF frame 690 → 691: 1028 differing pixels
# GIF frame 691 → 692: 969 differing pixels
# GIF frame 692 → 693: 963 differing pixels
# GIF frame 693 → 694: 1014 differing pixels
# GIF frame 694 → 695: 913 differing pixels
# GIF frame 695 → 696: 963 differing pixels
# GIF frame 696 → 697: 929 differing pixels
# GIF frame 697 → 698: 954 differing pixels
# GIF frame 698 → 699: 915 differing pixels
# GIF frame 699 → 700: 938 differing pixels
# GIF frame 700 → 701: 894 differing pixels
# GIF frame 701 → 702: 939 differing pixels
# GIF frame 702 → 703: 886 differing pixels
# GIF frame 703 → 704: 839 differing pixels
# GIF frame 704 → 705: 837 differing pixels
# GIF frame 705 → 706: 867 differing pixels
# GIF frame 706 → 707: 830 differing pixels
# GIF frame 707 → 708: 838 differing pixels
# GIF frame 708 → 709: 874 differing pixels
# GIF frame 709 → 710: 853 differing pixels
# GIF frame 710 → 711: 848 differing pixels
# GIF frame 711 → 712: 798 differing pixels
# GIF frame 712 → 713: 881 differing pixels
# GIF frame 713 → 714: 837 differing pixels
# GIF frame 714 → 715: 830 differing pixels
# GIF frame 715 → 716: 791 differing pixels
# GIF frame 716 → 717: 833 differing pixels
# GIF frame 717 → 718: 766 differing pixels
# GIF frame 718 → 719: 824 differing pixels
# GIF frame 719 → 720: 815 differing pixels
# GIF frame 720 → 721: 794 differing pixels
# GIF frame 721 → 722: 781 differing pixels
# GIF frame 722 → 723: 774 differing pixels
# GIF frame 723 → 724: 798 differing pixels
# GIF frame 724 → 725: 761 differing pixels
# GIF frame 725 → 726: 762 differing pixels
# GIF frame 726 → 727: 765 differing pixels
# GIF frame 727 → 728: 770 differing pixels
# GIF frame 728 → 729: 703 differing pixels
# GIF frame 729 → 730: 722 differing pixels
# GIF frame 730 → 731: 740 differing pixels
# GIF frame 731 → 732: 712 differing pixels
# GIF frame 732 → 733: 648 differing pixels
# GIF frame 733 → 734: 704 differing pixels
# GIF frame 734 → 735: 660 differing pixels
# GIF frame 735 → 736: 623 differing pixels
# GIF frame 736 → 737: 696 differing pixels
# GIF frame 737 → 738: 656 differing pixels
# GIF frame 738 → 739: 646 differing pixels
# GIF frame 739 → 740: 705 differing pixels
# GIF frame 740 → 741: 656 differing pixels
# GIF frame 741 → 742: 654 differing pixels
# GIF frame 742 → 743: 629 differing pixels
# GIF frame 743 → 744: 726 differing pixels
# GIF frame 744 → 745: 666 differing pixels
# GIF frame 745 → 746: 628 differing pixels
# GIF frame 746 → 747: 750 differing pixels
# GIF frame 747 → 748: 606 differing pixels
# GIF frame 748 → 749: 656 differing pixels
# GIF frame 749 → 750: 629 differing pixels
# GIF frame 750 → 751: 664 differing pixels
# GIF frame 751 → 752: 708 differing pixels
# GIF frame 752 → 753: 641 differing pixels
# GIF frame 753 → 754: 608 differing pixels
# GIF frame 754 → 755: 644 differing pixels
# GIF frame 755 → 756: 606 differing pixels
# GIF frame 756 → 757: 585 differing pixels
# GIF frame 757 → 758: 590 differing pixels
# GIF frame 758 → 759: 559 differing pixels
# GIF frame 759 → 760: 555 differing pixels
# GIF frame 760 → 761: 615 differing pixels
# GIF frame 761 → 762: 648 differing pixels
# GIF frame 762 → 763: 623 differing pixels
# GIF frame 763 → 764: 555 differing pixels
# GIF frame 764 → 765: 577 differing pixels
# GIF frame 765 → 766: 508 differing pixels
# GIF frame 766 → 767: 559 differing pixels
# GIF frame 767 → 768: 515 differing pixels
# GIF frame 768 → 769: 582 differing pixels
# GIF frame 769 → 770: 630 differing pixels
# GIF frame 770 → 771: 562 differing pixels
# GIF frame 771 → 772: 555 differing pixels
# GIF frame 772 → 773: 556 differing pixels
# GIF frame 773 → 774: 538 differing pixels
# GIF frame 774 → 775: 506 differing pixels
# GIF frame 775 → 776: 579 differing pixels
# GIF frame 776 → 777: 574 differing pixels
# GIF frame 777 → 778: 543 differing pixels
# GIF frame 778 → 779: 541 differing pixels
# GIF frame 779 → 780: 567 differing pixels
# GIF frame 780 → 781: 585 differing pixels
# GIF frame 781 → 782: 610 differing pixels
# GIF frame 782 → 783: 566 differing pixels
# GIF frame 783 → 784: 588 differing pixels
# GIF frame 784 → 785: 568 differing pixels
# GIF frame 785 → 786: 493 differing pixels
# GIF frame 786 → 787: 500 differing pixels
# GIF frame 787 → 788: 586 differing pixels
# GIF frame 788 → 789: 538 differing pixels
# GIF frame 789 → 790: 540 differing pixels
# GIF frame 790 → 791: 548 differing pixels
# GIF frame 791 → 792: 471 differing pixels
# GIF frame 792 → 793: 553 differing pixels
# GIF frame 793 → 794: 507 differing pixels
# GIF frame 794 → 795: 565 differing pixels
# GIF frame 795 → 796: 581 differing pixels
# GIF frame 796 → 797: 603 differing pixels
# GIF frame 797 → 798: 556 differing pixels
# GIF frame 798 → 799: 615 differing pixels
# GIF frame 799 → 800: 589 differing pixels
# GIF frame 800 → 801: 558 differing pixels
# GIF frame 801 → 802: 557 differing pixels
# GIF frame 802 → 803: 552 differing pixels
# GIF frame 803 → 804: 526 differing pixels
# GIF frame 804 → 805: 544 differing pixels
# GIF frame 805 → 806: 562 differing pixels
# GIF frame 806 → 807: 464 differing pixels
# GIF frame 807 → 808: 526 differing pixels
# GIF frame 808 → 809: 527 differing pixels
# GIF frame 809 → 810: 516 differing pixels
# GIF frame 810 → 811: 434 differing pixels
# GIF frame 811 → 812: 495 differing pixels
# GIF frame 812 → 813: 420 differing pixels
# GIF frame 813 → 814: 460 differing pixels
# GIF frame 814 → 815: 474 differing pixels
# GIF frame 815 → 816: 476 differing pixels
# GIF frame 816 → 817: 433 differing pixels
# GIF frame 817 → 818: 429 differing pixels
# GIF frame 818 → 819: 431 differing pixels
# GIF frame 819 → 820: 457 differing pixels
# GIF frame 820 → 821: 468 differing pixels
# GIF frame 821 → 822: 431 differing pixels
# GIF frame 822 → 823: 416 differing pixels
# GIF frame 823 → 824: 466 differing pixels
# GIF frame 824 → 825: 450 differing pixels
# GIF frame 825 → 826: 405 differing pixels
# GIF frame 826 → 827: 392 differing pixels
# GIF frame 827 → 828: 397 differing pixels
# GIF frame 828 → 829: 427 differing pixels
# GIF frame 829 → 830: 459 differing pixels
# GIF frame 830 → 831: 450 differing pixels
# GIF frame 831 → 832: 404 differing pixels
# GIF frame 832 → 833: 404 differing pixels
# GIF frame 833 → 834: 404 differing pixels
# GIF frame 834 → 835: 474 differing pixels
# GIF frame 835 → 836: 499 differing pixels
# GIF frame 836 → 837: 458 differing pixels
# GIF frame 837 → 838: 453 differing pixels
# GIF frame 838 → 839: 445 differing pixels
# GIF frame 839 → 840: 449 differing pixels
# GIF frame 840 → 841: 437 differing pixels
# GIF frame 841 → 842: 410 differing pixels
# GIF frame 842 → 843: 490 differing pixels
# GIF frame 843 → 844: 424 differing pixels
# GIF frame 844 → 845: 410 differing pixels
# GIF frame 845 → 846: 413 differing pixels
# GIF frame 846 → 847: 381 differing pixels
# GIF frame 847 → 848: 383 differing pixels
# GIF frame 848 → 849: 354 differing pixels
# GIF frame 849 → 850: 351 differing pixels
# GIF frame 850 → 851: 361 differing pixels
# GIF frame 851 → 852: 427 differing pixels
# GIF frame 852 → 853: 431 differing pixels
# GIF frame 853 → 854: 425 differing pixels
# GIF frame 854 → 855: 455 differing pixels
# GIF frame 855 → 856: 386 differing pixels
# GIF frame 856 → 857: 429 differing pixels
# GIF frame 857 → 858: 363 differing pixels
# GIF frame 858 → 859: 339 differing pixels
# GIF frame 859 → 860: 362 differing pixels
# GIF frame 860 → 861: 377 differing pixels
# GIF frame 861 → 862: 349 differing pixels
# GIF frame 862 → 863: 362 differing pixels
# GIF frame 863 → 864: 347 differing pixels
# GIF frame 864 → 865: 351 differing pixels
# GIF frame 865 → 866: 330 differing pixels
# GIF frame 866 → 867: 372 differing pixels
# GIF frame 867 → 868: 331 differing pixels
# GIF frame 868 → 869: 365 differing pixels
# GIF frame 869 → 870: 411 differing pixels
# GIF frame 870 → 871: 373 differing pixels
# GIF frame 871 → 872: 389 differing pixels
# GIF frame 872 → 873: 401 differing pixels
# GIF frame 873 → 874: 321 differing pixels
# GIF frame 874 → 875: 358 differing pixels
# GIF frame 875 → 876: 364 differing pixels
# GIF frame 876 → 877: 418 differing pixels
# GIF frame 877 → 878: 355 differing pixels
# GIF frame 878 → 879: 408 differing pixels
# GIF frame 879 → 880: 352 differing pixels
# GIF frame 880 → 881: 366 differing pixels
# GIF frame 881 → 882: 364 differing pixels
# GIF frame 882 → 883: 372 differing pixels
# GIF frame 883 → 884: 383 differing pixels
# GIF frame 884 → 885: 316 differing pixels
# GIF frame 885 → 886: 295 differing pixels
# GIF frame 886 → 887: 334 differing pixels
# GIF frame 887 → 888: 354 differing pixels
# GIF frame 888 → 889: 369 differing pixels
# GIF frame 889 → 890: 333 differing pixels
# GIF frame 890 → 891: 269 differing pixels
# GIF frame 891 → 892: 320 differing pixels
# GIF frame 892 → 893: 318 differing pixels
# GIF frame 893 → 894: 319 differing pixels
# GIF frame 894 → 895: 363 differing pixels
# GIF frame 895 → 896: 332 differing pixels
# GIF frame 896 → 897: 312 differing pixels
# GIF frame 897 → 898: 361 differing pixels
# GIF frame 898 → 899: 331 differing pixels
# GIF frame 899 → 900: 365 differing pixels
# GIF frame 900 → 901: 359 differing pixels
# GIF frame 901 → 902: 327 differing pixels
# GIF frame 902 → 903: 393 differing pixels
# GIF frame 903 → 904: 349 differing pixels
# GIF frame 904 → 905: 370 differing pixels
# GIF frame 905 → 906: 383 differing pixels
# GIF frame 906 → 907: 356 differing pixels
# GIF frame 907 → 908: 316 differing pixels
# GIF frame 908 → 909: 338 differing pixels
# GIF frame 909 → 910: 313 differing pixels
# GIF frame 910 → 911: 320 differing pixels
# GIF frame 911 → 912: 321 differing pixels
# GIF frame 912 → 913: 383 differing pixels
# GIF frame 913 → 914: 301 differing pixels
# GIF frame 914 → 915: 297 differing pixels
# GIF frame 915 → 916: 271 differing pixels
# GIF frame 916 → 917: 271 differing pixels
# GIF frame 917 → 918: 303 differing pixels
# GIF frame 918 → 919: 301 differing pixels
# GIF frame 919 → 920: 313 differing pixels
# GIF frame 920 → 921: 344 differing pixels
# GIF frame 921 → 922: 310 differing pixels
# GIF frame 922 → 923: 316 differing pixels
# GIF frame 923 → 924: 327 differing pixels
# GIF frame 924 → 925: 304 differing pixels
# GIF frame 925 → 926: 335 differing pixels
# GIF frame 926 → 927: 355 differing pixels
# GIF frame 927 → 928: 347 differing pixels
# GIF frame 928 → 929: 386 differing pixels
# GIF frame 929 → 930: 315 differing pixels
# GIF frame 930 → 931: 351 differing pixels
# GIF frame 931 → 932: 342 differing pixels
# GIF frame 932 → 933: 303 differing pixels
# GIF frame 933 → 934: 295 differing pixels
# GIF frame 934 → 935: 332 differing pixels
# GIF frame 935 → 936: 286 differing pixels
# GIF frame 936 → 937: 296 differing pixels
# GIF frame 937 → 938: 323 differing pixels
# GIF frame 938 → 939: 313 differing pixels
# GIF frame 939 → 940: 312 differing pixels
# GIF frame 940 → 941: 307 differing pixels
# GIF frame 941 → 942: 329 differing pixels
# GIF frame 942 → 943: 342 differing pixels
# GIF frame 943 → 944: 340 differing pixels
# GIF frame 944 → 945: 352 differing pixels
# GIF frame 945 → 946: 311 differing pixels
# GIF frame 946 → 947: 274 differing pixels
# GIF frame 947 → 948: 273 differing pixels
# GIF frame 948 → 949: 247 differing pixels
# GIF frame 949 → 950: 305 differing pixels
# GIF frame 950 → 951: 344 differing pixels
# GIF frame 951 → 952: 308 differing pixels
# GIF frame 952 → 953: 323 differing pixels
# GIF frame 953 → 954: 310 differing pixels
# GIF frame 954 → 955: 331 differing pixels
# GIF frame 955 → 956: 310 differing pixels
# GIF frame 956 → 957: 309 differing pixels
# GIF frame 957 → 958: 344 differing pixels
# GIF frame 958 → 959: 305 differing pixels
# GIF frame 959 → 960: 328 differing pixels
# GIF frame 960 → 961: 312 differing pixels
# GIF frame 961 → 962: 352 differing pixels
# GIF frame 962 → 963: 309 differing pixels
# GIF frame 963 → 964: 282 differing pixels
# GIF frame 964 → 965: 304 differing pixels
# GIF frame 965 → 966: 318 differing pixels
# GIF frame 966 → 967: 321 differing pixels
# GIF frame 967 → 968: 307 differing pixels
# GIF frame 968 → 969: 286 differing pixels
# GIF frame 969 → 970: 341 differing pixels
# GIF frame 970 → 971: 317 differing pixels
# GIF frame 971 → 972: 326 differing pixels
# GIF frame 972 → 973: 264 differing pixels
# GIF frame 973 → 974: 300 differing pixels
# GIF frame 974 → 975: 270 differing pixels
# GIF frame 975 → 976: 278 differing pixels
# GIF frame 976 → 977: 274 differing pixels
# GIF frame 977 → 978: 290 differing pixels
# GIF frame 978 → 979: 348 differing pixels
# GIF frame 979 → 980: 281 differing pixels
# GIF frame 980 → 981: 275 differing pixels
# GIF frame 981 → 982: 313 differing pixels
# GIF frame 982 → 983: 246 differing pixels
# GIF frame 983 → 984: 279 differing pixels
# GIF frame 984 → 985: 272 differing pixels
# GIF frame 985 → 986: 285 differing pixels
# GIF frame 986 → 987: 321 differing pixels
# GIF frame 987 → 988: 277 differing pixels
# GIF frame 988 → 989: 249 differing pixels
# GIF frame 989 → 990: 274 differing pixels
# GIF frame 990 → 991: 314 differing pixels
# GIF frame 991 → 992: 247 differing pixels
# GIF frame 992 → 993: 302 differing pixels
# GIF frame 993 → 994: 261 differing pixels
# GIF frame 994 → 995: 223 differing pixels
# GIF frame 995 → 996: 260 differing pixels
# GIF frame 996 → 997: 381 differing pixels
# GIF frame 997 → 998: 309 differing pixels
# GIF frame 998 → 999: 287 differing pixels
#
# ✅ The GIF shows motion between frames.
# GIF has 999 frames.

# %%
for file_ in file_names:
  if os.path.exists(file_):
      os.remove(file_)

files = os.listdir("/content")
file_names = []
for file_ in files:
    if file_.endswith("png"):
      os.remove(file_)

# %%
from google.colab import files
files.download('/content/particle_simulation.gif')
